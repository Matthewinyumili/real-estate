# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 6
import seaborn as sns

# %%
re=pd.read_csv('C:\\Users\\matth\\Downloads\\NSE_data_all_stocks_2018.csv')

# %%
re.describe()
# Out:
#              DATE   CODE         NAME 12m Low 12m High Day Low Day High  \
# count       17650  17650        17650   17650    17650   17650    17650
# unique        250     73           73     104      116    2343     2362
# top     31-Dec-18   EGAD  Eaagads Ltd       2     33.5       5        5
# freq           73    250          250     495      500     351      387
#
#        Day Price Previous Change Change% Volume Adjust
# count      17650    17650  17650   17650  17650  17650
# unique      2823     2815   1160     853   3703    233
# top            5        5      -       -      -      -
# freq         330      329   6935    6938   4985  16985

# %%
re.dtypes
# Out:
# DATE         object
# CODE         object
# NAME         object
# 12m Low      object
# 12m High     object
# Day Low      object
# Day High     object
# Day Price    object
# Previous     object
# Change       object
# Change%      object
# Volume       object
# Adjust       object
# dtype: object

# %%
re.head()
# Out:
#         DATE  CODE                     NAME 12m Low 12m High Day Low Day High  \
# 0  02-Jan-18  EGAD              Eaagads Ltd     8.2       14      25       25
# 1  02-Jan-18  KUKZ               Kakuzi Plc     300    423.5     329      329
# 2  02-Jan-18  KAPC  Kapchorua Tea Kenya Plc      59       95    67.5       70
# 3  02-Jan-18  LIMT           Limuru Tea Plc     385      475     500      500
# 4  02-Jan-18  SASN               Sasini Plc    14.8     19.6      27     27.5
#
#   Day Price Previous Change Change%  Volume Adjust
# 0        25    22.75   2.25   9.89%  10,500      -
# 1       329      329      -       -       -      -
# 2      67.5     65.5      2   3.05%   1,000      -
# 3       500      500      -       -       -      -
# 4        27     29.5   -2.5   8.47%     300      -

# %%
re.tail()
# Out:
#             DATE     CODE                             NAME   12m Low  \
# 17646  31-Dec-18    ^N25I               NSE 25-Share Index  2,943.60
# 17647  31-Dec-18    ^NASI              NSE All-Share Index     124.3
# 17648  31-Dec-18  ^ZKEQTK  Zamara Kenya Equity Index (KES)  1,513.07
# 17649  31-Dec-18  ^ZKEQTU  Zamara Kenya Equity Index (USD)  1,225.28
# 17650        NaN      NaN                              NaN       NaN
#
#        12m High   Day Low  Day High Day Price  Previous  Change Change%  \
# 17646  4,207.90  3,551.59  3,551.59  3,551.59  3,579.32  -27.73   0.77%
# 17647    171.36    140.43    140.43    140.43       142   -1.57   1.11%
# 17648  2,242.89  1,642.46  1,642.46  1,642.46  1,650.36    -7.9   0.48%
# 17649  1,905.40  1,388.47  1,388.47  1,388.47  1,394.46   -5.99   0.43%
# 17650       NaN       NaN       NaN       NaN       NaN     NaN     NaN
#
#       Volume Adjust
# 17646      -      -
# 17647      -      -
# 17648      -      -
# 17649      -      -
# ...

# %%
re.shape
# Out:
# (17651, 13)

# %%
re.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17651 entries, 0 to 17650
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       17650 non-null  object
#  1   CODE       17650 non-null  object
#  2   NAME       17650 non-null  object
#  3   12m Low    17650 non-null  object
#  4   12m High   17650 non-null  object
#  5   Day Low    17650 non-null  object
#  6   Day High   17650 non-null  object
#  7   Day Price  17650 non-null  object
#  8   Previous   17650 non-null  object
#  9   Change     17650 non-null  object
#  10  Change%    17650 non-null  object
#  11  Volume     17650 non-null  object
#  12  Adjust     17650 non-null  object
# dtypes: object(13)
# memory usage: 1.8+ MB

# %%
re.columns
# Out:
# Index(['DATE', 'CODE', 'NAME', '12m Low', '12m High', 'Day Low', 'Day High',
#        'Day Price', 'Previous', 'Change', 'Change%', 'Volume', 'Adjust'],
#       dtype='object')

# %% [markdown]
# # Drop only those rows where all the row values are null values

# %%
print(re.dropna(axis=0, how='all'))
# Out:
#             DATE     CODE                             NAME   12m Low  \
# 0      02-Jan-18     EGAD                      Eaagads Ltd       8.2
# 1      02-Jan-18     KUKZ                       Kakuzi Plc       300
# 2      02-Jan-18     KAPC          Kapchorua Tea Kenya Plc        59
# 3      02-Jan-18     LIMT                   Limuru Tea Plc       385
# 4      02-Jan-18     SASN                       Sasini Plc      14.8
# ...          ...      ...                              ...       ...
# 17645  31-Dec-18    ^N20I               NSE 20-Share Index  1,873.47
# 17646  31-Dec-18    ^N25I               NSE 25-Share Index  2,943.60
# 17647  31-Dec-18    ^NASI              NSE All-Share Index     124.3
# 17648  31-Dec-18  ^ZKEQTK  Zamara Kenya Equity Index (KES)  1,513.07
# 17649  31-Dec-18  ^ZKEQTU  Zamara Kenya Equity Index (USD)  1,225.28
#
#        12m High   Day Low  Day High Day Price  Previous  Change Change%  \
# ...

# %%
re.drop(['Day Low', 'Day High','CODE'], axis=1)
# Out:
#             DATE                             NAME   12m Low  12m High  \
# 0      02-Jan-18                      Eaagads Ltd       8.2        14
# 1      02-Jan-18                       Kakuzi Plc       300     423.5
# 2      02-Jan-18          Kapchorua Tea Kenya Plc        59        95
# 3      02-Jan-18                   Limuru Tea Plc       385       475
# 4      02-Jan-18                       Sasini Plc      14.8      19.6
# ...          ...                              ...       ...       ...
# 17646  31-Dec-18               NSE 25-Share Index  2,943.60  4,207.90
# 17647  31-Dec-18              NSE All-Share Index     124.3    171.36
# 17648  31-Dec-18  Zamara Kenya Equity Index (KES)  1,513.07  2,242.89
# 17649  31-Dec-18  Zamara Kenya Equity Index (USD)  1,225.28  1,905.40
# 17650        NaN                              NaN       NaN       NaN
#
#       Day Price  Previous  Change Change%  Volume Adjust
# 0            25     22.75    2.25   9.89%  10,500      -
# ...

# %%
def plot_re(df, x, y, title="", xlabel='DATE', ylabel='Volume', dpi=100):
    plt.figure(figsize=(15,4), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

# %%
sns.displot(data= re, x='Volume', kde=True , color='b')

# %%
X=re.drop('DATE', axis=1)

y=re['Volume']

# %%
print("X=",X.shape,"\ny=", y.shape)
# Out:
# X= (17651, 12)
# y= (17651,)
